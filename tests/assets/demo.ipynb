# %%
print("Hello world")

# %%
print("Hello World")
print("Hello World")

# %%
print("Hello World")
print("Hello World")
#% title="Hello World"

# %%
print("Hello World")
print("Hello World")
#% title="Hello World" highlights="1-5,3-4"

# %%
print("Hello World")
print("Hello World")
#% title="Hello World" highlights=1-5,3-4

# %%
print("Hello World")
print("Hello World")
#% title="Hello World"
